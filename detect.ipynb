# %%
#install dependencies
import torch 
from matplotlib import pyplot as plt
import numpy as np
import cv2

model = torch.hub.load('yolov5', 'custom', path='best.pt', source='local')

img = "tomato_green.jpg"

results = model(img)
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
results.show()
# Out:
# YOLOv5  2023-4-24 Python-3.11.2 torch-2.0.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# requirements: C:\Users\rgere\OneDrive\ \cs\cpproject\yolov5_tomato\content\requirements.txt not found, check failed.
# image 1/1: 399x500 11 Tomatos
# Speed: 5.0ms pre-process, 125.0ms inference, 1.0ms NMS per image at shape (1, 3, 512, 640)
# <PIL.Image.Image image mode=RGB size=500x399>
